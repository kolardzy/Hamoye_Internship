# %% [markdown]
# **Hamoye- Stage A Quiz**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Question 1**

# %%
#Question 1
A = [1,2,3,4,5,6] 
B = [13, 21, 34]

# %%
#Best way to combine them to form array A_B
A_B = A + B
print (A_B)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %% [markdown]
# **Question 2**

# %%
#Question 2
#Answer: A
C = np.identity(3)
print (C)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %% [markdown]
# **Question 3**

# %%
#Question 3
fuel_ferc1 = pd.read_csv(r'C:\Users\Kolade Olawoyin\Documents\Hamoye internship\fuel_ferc1.csv')
print(fuel_ferc1)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
fuel_ferc1 = pd.DataFrame(fuel_ferc1)
fuel_ferc1
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
#fuel_ferc1 in dataframe
fuel_ferc1 = pd.DataFrame(fuel_ferc1)
fuel_ferc1
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 4        f1_fuel_1994_12_2_0_10                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# 6         f1_fuel_1994_12_2_1_1                 2         1994
# 7        f1_fuel_1994_12_2_1_10                 2         1994
# 8        f1_fuel_1994_12_2_2_10                 2         1994
# 9         f1_fuel_1994_12_4_0_1                 4         1994
# 10        f1_fuel_1994_12_4_0_2                 4         1994
# 11        f1_fuel_1994_12_4_0_4                 4         1994
# 12        f1_fuel_1994_12_4_0_5                 4         1994
# 13        f1_fuel_1994_12_6_0_1                 6         1994
# ...

# %%
#Lowest average cost 
lowest_average_cost = fuel_ferc1.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()

# %%
lowest_average_cost
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# As we can see, Gas has the lowest with 13.659397

# %% [markdown]
# **Question 4**

# %%
#calculating the standard deviation
standard_dev = fuel_ferc1['fuel_mmbtu_per_unit'].std()
print (standard_dev)
# Out:
# 10.600220307806886

# %%
#calculating the 75th Percentile
Percentile = fuel_ferc1['fuel_mmbtu_per_unit'].quantile(0.75)
print (Percentile)
# Out:
# 17.006

# %% [markdown]
# **Question 5**

# %%
#calcuation the skewness
skew= fuel_ferc1['fuel_qty_burned'].skew()
print (skew)
# Out:
# 15.851495469109503

# %%
#calcuation the kurtosis
kurt= fuel_ferc1['fuel_qty_burned'].kurtosis()
print (kurt)
# Out:
# 651.3694501337732

# %% [markdown]
# **Question 6**

# %%
#checking for missing values
fuel_ferc1.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %% [markdown]
# fuel_unit, it has 180 missing values

# %%
#percent of missing values
percent_missing = fuel_ferc1.isnull().sum() * 100 / len(fuel_ferc1)

# %%
print(percent_missing)
# Out:
# record_id                       0.000000
# utility_id_ferc1                0.000000
# report_year                     0.000000
# plant_name_ferc1                0.000000
# fuel_type_code_pudl             0.000000
# fuel_unit                       0.609694
# fuel_qty_burned                 0.000000
# fuel_mmbtu_per_unit             0.000000
# fuel_cost_per_unit_burned       0.000000
# fuel_cost_per_unit_delivered    0.000000
# fuel_cost_per_mmbtu             0.000000
# dtype: float64

# %% [markdown]
# fuel_unit has 0.609%

# %% [markdown]
# **Question 7**

# %% [markdown]
# Categorical and Mode computation

# %% [markdown]
# **Question 8**

# %%
#comparing correlation coefficients between fuel_cost_per_unit_burned and other columns:
# with fuel_mmbtu_per_unit
corr1 = fuel_ferc1['fuel_cost_per_unit_burned'].corr(fuel_ferc1['fuel_mmbtu_per_unit'])
print (corr1)
# Out:
# -0.010033808428853057

# %%
#comparing correlation coefficients between fuel_cost_per_unit_burned and other columns:
# with fuel_qty_burned
corr2 = fuel_ferc1['fuel_cost_per_unit_burned'].corr(fuel_ferc1['fuel_qty_burned'])
print (corr2)
# Out:
# -0.018535416794825225

# %%
#comparing correlation coefficients between fuel_cost_per_unit_burned and other columns:
# with utility_id_ferc1
corr3 = fuel_ferc1['fuel_cost_per_unit_burned'].corr(fuel_ferc1['utility_id_ferc1'])
print (corr3)
# Out:
# -0.037862707599972595

# %%
#comparing correlation coefficients between fuel_cost_per_unit_burned and other columns:
# with fuel_cost_per_unit_delivered
corr4 = fuel_ferc1['fuel_cost_per_unit_burned'].corr(fuel_ferc1['fuel_cost_per_unit_delivered'])
print (corr4)
# Out:
# 0.011007403299165112

# %% [markdown]
# Answer: fuel_mmbtu_per_unit and fuel_cost_per_unit_delivered

# %% [markdown]
# **Question 9**

# %%
average_per_year = fuel_ferc1.groupby('report_year' )['fuel_cost_per_unit_burned'].mean()
average_per_year
# Out:
# report_year
# 1994    213.191996
# 1995    354.422555
# 1996     79.434995
# 1997    149.482132
# 1998    126.683519
# 1999    120.053605
# 2000    237.797111
# 2001    133.013010
# 2002    101.179365
# 2003    123.183919
# 2004    154.897398
# 2005    107.111221
# 2006    151.361249
# 2007    202.622082
# 2008    255.954415
# 2009    215.699318
# 2010    262.951203
# 2011    301.754519
# 2012    258.804138
# 2013    255.991023
# 2014    442.359068
# 2015    237.933197
# 2016    247.083959
# 2017    246.281796
# 2018    232.992036
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
year1994 = 213.191996
year1998 = 126.683519
pct_change = ((year1998 - year1994)/year1998) *100
pct_change
# Out:
# -68.2870808159347

# %% [markdown]
# **Question 10**

# %%
Highest_year = fuel_ferc1.groupby('report_year')['fuel_cost_per_unit_delivered'].max()
Highest_year
# Out:
# report_year
# 1994      45115.000
# 1995       2396.770
# 1996    7793482.000
# 1997    7964521.000
# 1998     270604.000
# 1999       2891.100
# 2000    1168000.000
# 2001      34381.000
# 2002      31416.000
# 2003      34518.000
# 2004     132884.000
# 2005       8651.000
# 2006       1431.000
# 2007       4850.872
# 2008      10490.000
# 2009     730166.000
# 2010      44033.320
# 2011       9545.000
# 2012      10129.000
# 2013     135315.000
# 2014     136410.000
# 2015     140706.000
# 2016      69440.000
# 2017       3584.335
# 2018     245652.000
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %% [markdown]
# **Therefore, it is year 1997 with 7964521.000**
